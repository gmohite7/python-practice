# %% [markdown]
# Requirements
# Function to implement
# def top_error_codes(log_lines: list[str], n: int) -> list[tuple[int, int]]:
#     """
#     Returns a list of (status_code, count) sorted by:
#     1) count descending
#     2) status_code ascending (tie-break)
#     Length of result <= n
#     """
#
# Parsing rule (important)
#
# A status code is the first 3-digit number in the line that is between 100 and 599.
#
# Example: "GET /x 404 123ms" → status code is 404
#
# Example: "500 Internal Server Error (retry 2)" → status code is 500
#
# Example: "User 123 logged in 200 OK" → first 3-digit number is 123 (but 123 is not an error, so ignore that line)

# %%
def top_error_codes(log_lines: list[str], n: int) -> list[tuple[int, int]]:
    """
    Returns a list of (status_code, count) sorted by:
    1) count descending
    2) status_code ascending (tie-break)
    Length of result <= n
    """
    print('Hello world')

# %%
logs = [
  "2026-01-22 GET /api/users 200 15ms",
  "2026-01-22 GET /api/users 404 2ms",
  "2026-01-22 POST /api/login 500 80ms",
  "2026-01-22 GET /health 200 1ms",
  "2026-01-22 GET /api/users 404 3ms",
  "2026-01-22 POST /api/login 500 70ms",
]
top_error_codes(logs, 2)
# Out:
# Hello world
