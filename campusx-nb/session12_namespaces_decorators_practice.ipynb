# %%
#local and global variable
a = 4

def temp():
    #local variable
    b = 3
    print(b)

print(a)

temp()
# Out:
# 4
# 3

# %%
# local and global same variable

a = 4

def temp():
    a = 2
    print(a)

temp()
print(a)
# Out:
# 2
# 4
